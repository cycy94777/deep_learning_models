# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(columns=['EIN', 'NAME'])
application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
value_counts = application_df['APPLICATION_TYPE'].value_counts()
value_counts
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
cutoff = 1000
application_types_to_replace = value_counts[value_counts < cutoff].index

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# Other     2266
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
calssification = application_df['CLASSIFICATION'].value_counts()
calssification
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
calssification[calssification>1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
class_cutoff = 500
classifications_to_replace = calssification[calssification< class_cutoff].index
# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# Other     1484
# C7000      777
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
cat_df = pd.get_dummies(application_df)
application_df = application_df.merge(cat_df, left_index=True, right_index=True)
application_df = application_df.drop(columns= ['APPLICATION_TYPE', 'AFFILIATION', 'CLASSIFICATION', 'USE_CASE',
       'ORGANIZATION',  'SPECIAL_CONSIDERATIONS','INCOME_AMT'])
application_df.head()
# Out:
#    STATUS_x  ASK_AMT_x  IS_SUCCESSFUL_x  STATUS_y  ASK_AMT_y  IS_SUCCESSFUL_y  \
# 0         1       5000                1         1       5000                1
# 1         1     108590                1         1     108590                1
# 2         1       5000                0         1       5000                0
# 3         1       6692                1         1       6692                1
# 4         1     142590                1         1     142590                1
#
#    APPLICATION_TYPE_Other  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                       1                     0                    0
# 1                       0                     0                    1
# 2                       0                     0                    0
# 3                       0                     0                    1
# 4                       0                     0                    1
#
#    APPLICATION_TYPE_T4  ...  INCOME_AMT_1-9999  INCOME_AMT_10000-24999  \
# 0                    0  ...                  0                       0
# 1                    0  ...                  1                       0
# 2                    0  ...                  0                       0
# 3                    0  ...                  0                       1
# 4                    0  ...                  0                       0
#
#    INCOME_AMT_100000-499999  INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  \
# 0                         0                   0                 0
# 1                         0                   0                 0
# 2                         0                   0                 0
# 3                         0                   0                 0
# 4                         1                   0                 0
#
#    INCOME_AMT_25000-99999  INCOME_AMT_50M+  INCOME_AMT_5M-10M  \
# 0                       0                0                  0
# 1                       0                0                  0
# 2                       0                0                  0
# 3                       0                0                  0
# 4                       0                0                  0
#
#    SPECIAL_CONSIDERATIONS_N  SPECIAL_CONSIDERATIONS_Y
# 0                         1                         0
# 1                         1                         0
# 2                         1                         0
# 3                         1                         0
# 4                         1                         0
#
# [5 rows x 45 columns]

# %%
# Split our preprocessed data into our features and target arrays
y = cat_df['IS_SUCCESSFUL'].values
X = cat_df.drop(columns=['IS_SUCCESSFUL'],axis=1).values
# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
y_train = y_train.reshape(-1, 1)
y_test = y_test.reshape(-1, 1)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.


nn = tf.keras.models.Sequential()

# First hidden layer
first_layer = tf.keras.layers.Dense(units=20, input_dim=len(X_train[0]), activation='relu')
nn.add(first_layer)
# Second hidden layer
second_layer = tf.keras.layers.Dense(units=10, activation='relu')
nn.add(second_layer)
# Output layer
output_layer = tf.keras.layers.Dense(units=1, activation='sigmoid')
nn.add(output_layer)
# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 20)                840
#
#  dense_1 (Dense)             (None, 10)                210
#
#  dense_2 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 1,061
# Trainable params: 1,061
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
import os
from tensorflow.keras.callbacks import ModelCheckpoint
os.makedirs('checkpoints/', exist_ok=True)
checkpoint_filepath = 'checkpoints/model_weights.{epoch:02d}.h5'
checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    period=5,

)
fit_model = nn.fit(X_train_scaled, y_train, epochs=100, callbacks=[checkpoint_callback], verbose=2)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/100
# 804/804 - 4s - loss: 0.5872 - accuracy: 0.7093 - 4s/epoch - 5ms/step
# Epoch 2/100
# 804/804 - 4s - loss: 0.5620 - accuracy: 0.7266 - 4s/epoch - 5ms/step
# Epoch 3/100
# 804/804 - 2s - loss: 0.5575 - accuracy: 0.7285 - 2s/epoch - 3ms/step
# Epoch 4/100
# 804/804 - 3s - loss: 0.5550 - accuracy: 0.7280 - 3s/epoch - 4ms/step
# Epoch 5/100
# 804/804 - 2s - loss: 0.5544 - accuracy: 0.7296 - 2s/epoch - 3ms/step
# Epoch 6/100
# 804/804 - 2s - loss: 0.5534 - accuracy: 0.7292 - 2s/epoch - 3ms/step
# Epoch 7/100
# 804/804 - 3s - loss: 0.5525 - accuracy: 0.7304 - 3s/epoch - 4ms/step
# Epoch 8/100
# 804/804 - 2s - loss: 0.5515 - accuracy: 0.7305 - 2s/epoch - 3ms/step
# Epoch 9/100
# 804/804 - 1s - loss: 0.5515 - accuracy: 0.7308 - 1s/epoch - 1ms/step
# Epoch 10/100
# 804/804 - 1s - loss: 0.5502 - accuracy: 0.7324 - 1s/epoch - 1ms/step
# Epoch 11/100
# 804/804 - 1s - loss: 0.5498 - accuracy: 0.7318 - 1s/epoch - 1ms/step
# Epoch 12/100
# 804/804 - 1s - loss: 0.5500 - accuracy: 0.7320 - 1s/epoch - 1ms/step
# Epoch 13/100
# 804/804 - 1s - loss: 0.5494 - accuracy: 0.7318 - 1s/epoch - 2ms/step
# Epoch 14/100
# 804/804 - 1s - loss: 0.5492 - accuracy: 0.7326 - 1s/epoch - 1ms/step
# Epoch 15/100
# 804/804 - 2s - loss: 0.5489 - accuracy: 0.7329 - 2s/epoch - 2ms/step
# Epoch 16/100
# 804/804 - 2s - loss: 0.5487 - accuracy: 0.7327 - 2s/epoch - 2ms/step
# Epoch 17/100
# 804/804 - 1s - loss: 0.5487 - accuracy: 0.7329 - 1s/epoch - 1ms/step
# Epoch 18/100
# 804/804 - 1s - loss: 0.5479 - accuracy: 0.7325 - 1s/epoch - 1ms/step
# Epoch 19/100
# 804/804 - 1s - loss: 0.5482 - accuracy: 0.7335 - 1s/epoch - 1ms/step
# Epoch 20/100
# 804/804 - 1s - loss: 0.5476 - accuracy: 0.7318 - 1s/epoch - 2ms/step
# Epoch 21/100
# 804/804 - 1s - loss: 0.5478 - accuracy: 0.7334 - 1s/epoch - 2ms/step
# Epoch 22/100
# 804/804 - 1s - loss: 0.5478 - accuracy: 0.7336 - 1s/epoch - 1ms/step
# Epoch 23/100
# 804/804 - 1s - loss: 0.5472 - accuracy: 0.7334 - 1s/epoch - 1ms/step
# Epoch 24/100
# 804/804 - 1s - loss: 0.5474 - accuracy: 0.7328 - 1s/epoch - 1ms/step
# Epoch 25/100
# 804/804 - 2s - loss: 0.5468 - accuracy: 0.7337 - 2s/epoch - 2ms/step
# Epoch 26/100
# 804/804 - 2s - loss: 0.5472 - accuracy: 0.7346 - 2s/epoch - 2ms/step
# Epoch 27/100
# 804/804 - 1s - loss: 0.5468 - accuracy: 0.7330 - 1s/epoch - 1ms/step
# Epoch 28/100
# 804/804 - 1s - loss: 0.5471 - accuracy: 0.7325 - 1s/epoch - 2ms/step
# Epoch 29/100
# 804/804 - 1s - loss: 0.5469 - accuracy: 0.7347 - 1s/epoch - 1ms/step
# Epoch 30/100
# 804/804 - 1s - loss: 0.5465 - accuracy: 0.7334 - 1s/epoch - 2ms/step
# Epoch 31/100
# 804/804 - 1s - loss: 0.5465 - accuracy: 0.7345 - 1s/epoch - 1ms/step
# Epoch 32/100
# 804/804 - 1s - loss: 0.5462 - accuracy: 0.7337 - 1s/epoch - 1ms/step
# Epoch 33/100
# 804/804 - 1s - loss: 0.5461 - accuracy: 0.7343 - 1s/epoch - 1ms/step
# Epoch 34/100
# 804/804 - 1s - loss: 0.5463 - accuracy: 0.7338 - 1s/epoch - 1ms/step
# Epoch 35/100
# 804/804 - 2s - loss: 0.5458 - accuracy: 0.7332 - 2s/epoch - 2ms/step
# Epoch 36/100
# 804/804 - 2s - loss: 0.5462 - accuracy: 0.7341 - 2s/epoch - 2ms/step
# Epoch 37/100
# 804/804 - 1s - loss: 0.5458 - accuracy: 0.7339 - 1s/epoch - 1ms/step
# Epoch 38/100
# 804/804 - 1s - loss: 0.5458 - accuracy: 0.7347 - 1s/epoch - 1ms/step
# Epoch 39/100
# 804/804 - 1s - loss: 0.5452 - accuracy: 0.7336 - 1s/epoch - 2ms/step
# Epoch 40/100
# 804/804 - 2s - loss: 0.5451 - accuracy: 0.7351 - 2s/epoch - 2ms/step
# Epoch 41/100
# 804/804 - 1s - loss: 0.5450 - accuracy: 0.7339 - 1s/epoch - 2ms/step
# Epoch 42/100
# 804/804 - 1s - loss: 0.5450 - accuracy: 0.7348 - 1s/epoch - 1ms/step
# Epoch 43/100
# 804/804 - 1s - loss: 0.5451 - accuracy: 0.7336 - 1s/epoch - 2ms/step
# Epoch 44/100
# 804/804 - 1s - loss: 0.5450 - accuracy: 0.7355 - 1s/epoch - 2ms/step
# Epoch 45/100
# 804/804 - 2s - loss: 0.5450 - accuracy: 0.7349 - 2s/epoch - 2ms/step
# Epoch 46/100
# 804/804 - 1s - loss: 0.5445 - accuracy: 0.7355 - 1s/epoch - 2ms/step
# Epoch 47/100
# 804/804 - 1s - loss: 0.5447 - accuracy: 0.7351 - 1s/epoch - 2ms/step
# Epoch 48/100
# 804/804 - 1s - loss: 0.5444 - accuracy: 0.7344 - 1s/epoch - 2ms/step
# Epoch 49/100
# 804/804 - 1s - loss: 0.5445 - accuracy: 0.7344 - 1s/epoch - 1ms/step
# Epoch 50/100
# 804/804 - 1s - loss: 0.5444 - accuracy: 0.7354 - 1s/epoch - 2ms/step
# Epoch 51/100
# 804/804 - 1s - loss: 0.5440 - accuracy: 0.7355 - 1s/epoch - 1ms/step
# Epoch 52/100
# 804/804 - 1s - loss: 0.5438 - accuracy: 0.7348 - 1s/epoch - 1ms/step
# Epoch 53/100
# 804/804 - 1s - loss: 0.5440 - accuracy: 0.7354 - 1s/epoch - 1ms/step
# Epoch 54/100
# 804/804 - 1s - loss: 0.5439 - accuracy: 0.7360 - 1s/epoch - 2ms/step
# Epoch 55/100
# 804/804 - 2s - loss: 0.5439 - accuracy: 0.7349 - 2s/epoch - 2ms/step
# Epoch 56/100
# 804/804 - 1s - loss: 0.5436 - accuracy: 0.7358 - 1s/epoch - 2ms/step
# Epoch 57/100
# 804/804 - 1s - loss: 0.5434 - accuracy: 0.7347 - 1s/epoch - 1ms/step
# Epoch 58/100
# 804/804 - 1s - loss: 0.5435 - accuracy: 0.7359 - 1s/epoch - 2ms/step
# Epoch 59/100
# 804/804 - 1s - loss: 0.5435 - accuracy: 0.7353 - 1s/epoch - 1ms/step
# Epoch 60/100
# 804/804 - 1s - loss: 0.5432 - accuracy: 0.7358 - 1s/epoch - 2ms/step
# Epoch 61/100
# 804/804 - 1s - loss: 0.5435 - accuracy: 0.7366 - 1s/epoch - 1ms/step
# Epoch 62/100
# 804/804 - 1s - loss: 0.5435 - accuracy: 0.7348 - 1s/epoch - 2ms/step
# Epoch 63/100
# 804/804 - 1s - loss: 0.5430 - accuracy: 0.7370 - 1s/epoch - 2ms/step
# Epoch 64/100
# 804/804 - 2s - loss: 0.5426 - accuracy: 0.7354 - 2s/epoch - 2ms/step
# Epoch 65/100
# 804/804 - 3s - loss: 0.5431 - accuracy: 0.7354 - 3s/epoch - 3ms/step
# Epoch 66/100
# 804/804 - 2s - loss: 0.5430 - accuracy: 0.7362 - 2s/epoch - 2ms/step
# Epoch 67/100
# 804/804 - 2s - loss: 0.5427 - accuracy: 0.7358 - 2s/epoch - 3ms/step
# Epoch 68/100
# 804/804 - 2s - loss: 0.5429 - accuracy: 0.7355 - 2s/epoch - 3ms/step
# Epoch 69/100
# 804/804 - 2s - loss: 0.5431 - accuracy: 0.7358 - 2s/epoch - 3ms/step
# Epoch 70/100
# 804/804 - 3s - loss: 0.5430 - accuracy: 0.7361 - 3s/epoch - 4ms/step
# Epoch 71/100
# 804/804 - 3s - loss: 0.5426 - accuracy: 0.7369 - 3s/epoch - 4ms/step
# Epoch 72/100
# 804/804 - 3s - loss: 0.5428 - accuracy: 0.7355 - 3s/epoch - 4ms/step
# Epoch 73/100
# 804/804 - 2s - loss: 0.5425 - accuracy: 0.7362 - 2s/epoch - 3ms/step
# Epoch 74/100
# 804/804 - 1s - loss: 0.5425 - accuracy: 0.7353 - 1s/epoch - 2ms/step
# Epoch 75/100
# 804/804 - 1s - loss: 0.5428 - accuracy: 0.7374 - 1s/epoch - 2ms/step
# Epoch 76/100
# 804/804 - 2s - loss: 0.5426 - accuracy: 0.7366 - 2s/epoch - 2ms/step
# Epoch 77/100
# 804/804 - 1s - loss: 0.5426 - accuracy: 0.7353 - 1s/epoch - 2ms/step
# Epoch 78/100
# 804/804 - 1s - loss: 0.5423 - accuracy: 0.7364 - 1s/epoch - 1ms/step
# Epoch 79/100
# 804/804 - 1s - loss: 0.5426 - accuracy: 0.7370 - 1s/epoch - 1ms/step
# Epoch 80/100
# 804/804 - 1s - loss: 0.5425 - accuracy: 0.7359 - 1s/epoch - 1ms/step
# Epoch 81/100
# 804/804 - 1s - loss: 0.5421 - accuracy: 0.7366 - 1s/epoch - 1ms/step
# Epoch 82/100
# 804/804 - 1s - loss: 0.5423 - accuracy: 0.7364 - 1s/epoch - 1ms/step
# Epoch 83/100
# 804/804 - 1s - loss: 0.5421 - accuracy: 0.7366 - 1s/epoch - 1ms/step
# Epoch 84/100
# 804/804 - 1s - loss: 0.5425 - accuracy: 0.7370 - 1s/epoch - 1ms/step
# Epoch 85/100
# 804/804 - 1s - loss: 0.5418 - accuracy: 0.7374 - 1s/epoch - 2ms/step
# Epoch 86/100
# 804/804 - 2s - loss: 0.5421 - accuracy: 0.7367 - 2s/epoch - 2ms/step
# Epoch 87/100
# 804/804 - 1s - loss: 0.5418 - accuracy: 0.7370 - 1s/epoch - 2ms/step
# Epoch 88/100
# 804/804 - 1s - loss: 0.5423 - accuracy: 0.7365 - 1s/epoch - 1ms/step
# Epoch 89/100
# 804/804 - 1s - loss: 0.5419 - accuracy: 0.7372 - 1s/epoch - 1ms/step
# Epoch 90/100
# 804/804 - 1s - loss: 0.5419 - accuracy: 0.7369 - 1s/epoch - 1ms/step
# Epoch 91/100
# 804/804 - 1s - loss: 0.5417 - accuracy: 0.7361 - 1s/epoch - 1ms/step
# Epoch 92/100
# 804/804 - 1s - loss: 0.5420 - accuracy: 0.7361 - 1s/epoch - 1ms/step
# Epoch 93/100
# 804/804 - 1s - loss: 0.5419 - accuracy: 0.7370 - 1s/epoch - 1ms/step
# Epoch 94/100
# 804/804 - 1s - loss: 0.5417 - accuracy: 0.7365 - 1s/epoch - 1ms/step
# Epoch 95/100
# 804/804 - 2s - loss: 0.5416 - accuracy: 0.7375 - 2s/epoch - 2ms/step
# Epoch 96/100
# 804/804 - 2s - loss: 0.5416 - accuracy: 0.7369 - 2s/epoch - 2ms/step
# Epoch 97/100
# 804/804 - 1s - loss: 0.5419 - accuracy: 0.7367 - 1s/epoch - 2ms/step
# Epoch 98/100
# 804/804 - 1s - loss: 0.5416 - accuracy: 0.7372 - 1s/epoch - 1ms/step
# Epoch 99/100
# 804/804 - 1s - loss: 0.5418 - accuracy: 0.7367 - 1s/epoch - 1ms/step
# Epoch 100/100
# 804/804 - 1s - loss: 0.5422 - accuracy: 0.7376 - 1s/epoch - 2ms/step

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5549 - accuracy: 0.7318 - 470ms/epoch - 2ms/step
# Loss: 0.5548706650733948, Accuracy: 0.7317784428596497

# %%
history_df = pd.DataFrame(fit_model.history)
history_df.index +=1
accuracy_plot = history_df.plot(y='accuracy')
import matplotlib.pyplot as plt
plt.title("Original Model's Accuracy ")
plt.xlabel("Epochs")
plt.savefig("accuracy.png")

# %%
import matplotlib.pyplot as plt
plt.savefig("accuracy.png")

# %%
# Export our model to HDF5 file
nn.save('../Models/AlphabetSoupCharity.h5')
